# %%
#dependencies
import pandas as pd
import numpy as np

# %%
game_csv = "2009.csv"
team_code="teamcodemaster.csv"


game_df = pd.read_csv(game_csv)
team_df= pd.read_csv(team_code)

# %%
game_df.head()
# Out:
#    Team Code     Game Code  Rush Att  Rush Yard  Rush TD  Pass Att  Pass Comp  \
# 0          5  5.053920e+12        30         28        0        24         13
# 1          5  4.460010e+14        49        250        1        28         16
# 2          5  3.060010e+14        30        106        1        23         14
# 3          5  5.012920e+12        37         69        3        19         12
# 4          5  5.190010e+14        34        159        1        42         19
#
#    Pass Yard  Pass TD  Pass Int  ...  Time Of Possession  Penalty  \
# 0        158        1         1  ...                1519        7
# 1        186        3         0  ...                2088        1
# 2        165        1         4  ...                1509        5
# 3        127        0         0  ...                1479        6
# 4        187        0         2  ...                1587        6
#
#    Penalty Yard  Third Down Att  Third Down Conv  Fourth Down Att  \
# ...

# %%
team_df.head()
# Out:
#    Team Code           Name  Conference Code  Unnamed: 3  Unnamed: 4
# 0          8        Alabama              911         NaN         NaN
# 1         29        Arizona              905         NaN         NaN
# 2         28  Arizona State              905         NaN         NaN
# 3         31       Arkansas              911         NaN         NaN
# 4         37         Auburn              911         NaN         NaN

# %%
 # Merge the two DataFrames together based on the Team Code
stats_df = pd.merge(game_df, team_df, on="Team Code")
stats_df.tail()
# Out:
#      Team Code     Game Code  Rush Att  Rush Yard  Rush TD  Pass Att  \
# 825        796  7.960310e+14        52        294        3        20
# 826        796  4.180800e+14        52        229        2        24
# 827        796  7.960510e+14        35         99        1        30
# 828        796  7.960280e+14        52        301        7        20
# 829        796  4.150800e+14        42        170        2        26
#
#      Pass Comp  Pass Yard  Pass TD  Pass Int  ...  Third Down Conv  \
# 825         11        194        1         0  ...               11
# 826         16        240        4         1  ...                6
# 827         19        235        2         1  ...                4
# 828         16        253        0         0  ...                8
# 829         19        260        0         1  ...                6
#
#      Fourth Down Att  Fourth Down Conv  Red Zone Att  Red Zone TD  \
# 825                0                 0             5            4
# ...

# %%
# Identify incomplete rows
stats_df.count()
# Out:
# Team Code               830
# Game Code               830
# Rush Att                830
# Rush Yard               830
# Rush TD                 830
# Pass Att                830
# Pass Comp               830
# Pass Yard               830
# Pass TD                 830
# Pass Int                830
# Pass Conv               830
# Kickoff Ret             830
# Kickoff Ret Yard        830
# Kickoff Ret TD          830
# Punt Ret                830
# Punt Ret Yard           830
# Punt Ret TD             830
# Fum Ret                 830
# Fum Ret Yard            830
# Fum Ret TD              830
# Int Ret                 830
# Int Ret Yard            830
# Int Ret TD              830
# Misc Ret                830
# Misc Ret Yard           830
# Misc Ret TD             830
# Field Goal Att          830
# Field Goal Made         830
# Off XP Kick Att         830
# Off XP Kick Made        830
#                        ...
# Kickoff Onside          830
# Fumble                  830
# ...

# %%
# Drop all rows with missing information
#game_stats_df= df.drop([])

stats_df.to_csv
# Out:
# <bound method NDFrame.to_csv of      Team Code     Game Code  Rush Att  Rush Yard  Rush TD  Pass Att  \
# 0            8  8.074220e+12        49        268        2        30
# 1            8  2.310010e+14        42        275        4        24
# 2            8  4.970010e+14        45        260        5        28
# 3            8  3.100080e+13        41        134        2        24
# 4            8  8.033420e+12        42        204        2        26
# 5            8  8.043320e+12        41        200        1        35
# 6            8  6.480010e+14        38        264        1        20
# 7            8  6.940010e+14        30        136        0        29
# 8            8  3.650010e+14        38        176        0        34
# 9            8  8.043020e+12        40        252        2        18
# 10           8  6.930010e+14        56        313        4        16
# 11           8  8.003720e+12        35         73        1        32
# ...
